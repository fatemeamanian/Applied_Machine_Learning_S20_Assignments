# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import sklearn

# %%
start_time = time.time()
data = {'a': np.arange(500),
        'c': np.random.randint(0, 500, 500),
        'd': np.random.randn(500)}
data['b'] = data['a'] + 10 * np.random.randn(500)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()
df = pd.DataFrame(np.random.randn(10, 4)) 
print(df)

j=1.23
for i in range(80000000):
  j+=j    

print("\n-> Execution Time = %s in Seconds <-" % (time.time() - start_time))
# Out:
#           0         1         2         3
# 0 -0.399468  0.362335 -2.061577 -0.329517
# 1  0.103052  0.832735 -2.117324  0.574735
# 2  2.313330  0.246542 -0.807671 -1.182232
# 3  1.157849 -0.877646  0.107678 -0.631833
# 4 -0.350433 -1.376840  0.898522 -0.389223
# 5 -0.638260  0.092536  0.211226 -0.438011
# 6  1.853094  2.174853  0.705098  0.996906
# 7 -0.852274 -1.497083 -0.266960  0.235562
# 8 -0.816860  0.752286 -0.038081 -1.444299
# 9 -0.266685  1.231014 -0.265244 -0.770332
#
# -> Execution Time = 10.061602354049683 in Seconds <-
